# %% [markdown]
# TODO:
# - ~~movie~~
# - ~~gs~~
# - ~~more interesting BC~~
# - ~~more interesting f~~
# - __more interesting domains__
# - ~~random strategy~~

# %% [markdown]
# - MC random
# - MC f=-1, g=0
# - branch 1:
#     - A:
#         - W1: equal
#         - W2: change jump
#     - B:
#         - W1: equal
#         - W2: change probs
# - branch 2:
#     - beyond nearest neighbors
